# %% [markdown]
# # How do bacterial strains deposited in NCBI change over time?

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>
#
# <!--- This produces the "show code" button. From http://chris-said.io/2016/02/13/how-to-make-polished-jupyter-presentations-with-optional-code-visibility/ --->

# %%
#imports 
import pandas
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
my_file = "prokaryotes.txt" #hardcoded- bad! 
# reading in initial data set:
data_frame = pandas.read_csv(my_file, sep = '\t', header = 'infer', 
                             low_memory = False)

#stolen from Beth. Should make data imports etc into some functions. 
#How would we write tests for that? 
#(so changes to the helper functions don't break other ppls code)
data_frame['Release Date'] = pandas.to_datetime(data_frame['Release Date'])

#set index
data_frame.index = data_frame['Release Date']

#Group by TaxID AND 
#count number of submissions every 3 months
data_frame_grouped = data_frame.groupby("TaxID").resample("3M").count()
#also group by year
data_frame_year = data_frame.groupby("#Organism/Name").resample("Y").count()

# %%
data_frame_year = data_frame_year['Strain'].unstack("#Organism/Name") 
##returns the rows (TaxIDs) with the largest number of entries, 
#for each year
#needs to be done before grouping. 
top_per_year = data_frame_year.idxmax(axis=1)
top_overall = df.sum().sort_values().iloc[-15:]

#we don't need this
top_overall_list = list(top_overall.index)

col_order = df.sum().sort_values(inplace=False).index

# %% [markdown]
# ## What strains are most popular each year?

# %%
#Unsure how to do this. By name is susceptible to typos.
#But TaxID is inconsistent, as some organisms have multiple. 
#Does this matter? 
top_per_year
# Out:
# Release Date
# 1995-12-31                       Haemophilus influenzae Rd KW20
# 1996-12-31                           Mycoplasma pneumoniae M129
# 1997-12-31                                 Aquifex aeolicus VF5
# 1998-12-31                      Chlamydia trachomatis D/UW-3/CX
# 1999-12-31                          Chlamydia pneumoniae CWL029
# 2000-12-31                        Chlamydia muridarum str. Nigg
# 2001-12-31                        Agrobacterium fabrum str. C58
# 2002-12-31                        Bacillus anthracis str. A2012
# 2003-12-31    Actinobacillus pleuropneumoniae serovar 1 str....
# 2004-12-31           Bacillus licheniformis DSM 13 = ATCC 14580
# 2005-12-31                            Aliivibrio fischeri ES114
# 2006-12-31                      Acidothermus cellulolyticus 11B
# 2007-12-31                     Mycobacterium tuberculosis H37Ra
# 2008-12-31            Acidithiobacillus ferrooxidans ATCC 23270
# 2009-12-31                                    Bacillus mycoides
# 2010-12-31    Actinobacillus pleuropneumoniae serovar 6 str....
# 2011-12-31                Escherichia coli O104:H4 str. TY-2482
# 2012-12-31            Staphylococcus aureus subsp. aureus ST228
# 2013-12-31                               Listeria monocytogenes
# 2014-12-31                                     Escherichia coli
# 2015-12-31                             Streptococcus pneumoniae
# 2016-12-31                             Streptococcus pneumoniae
# 2017-12-31                                     Escherichia coli
# 2018-12-31                                     Escherichia coli
# dtype: object

# %%
df = data_frame_grouped['Strain'].unstack("TaxID") 
df1=np.split(df[col_order], [-20], axis=1)

#Combines these dataframes, summing all small values to combine them
final_df = pandas.concat([df1[1], df1[0].sum(axis=1)], axis=1)

#Make the plot! 
final_df.plot.area()
plt.show()
