# %% [markdown]
# # How do bacterial strains deposited in NCBI change over time?

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>
#
# <!--- This produces the "show code" button. From http://chris-said.io/2016/02/13/how-to-make-polished-jupyter-presentations-with-optional-code-visibility/ Note that this will break code when you try to save the notebook as pdf--->

# %%
#imports 
#%reset
import pandas
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as scipy
from st_helper_functions import *

# %%
my_file = "prokaryotes.txt" #hardcoded- bad! 
# reading in initial data set:
data_frame = pandas.read_csv(my_file, sep = '\t', header = 'infer', 
                             low_memory = False)

#stolen from Beth. Should make data imports etc into some functions. 
#How would we write tests for that? 
data_frame['Release Date'] = pandas.to_datetime(data_frame['Release Date'])

#set index
data_frame.index = data_frame['Release Date']
  
df = group_df_by(data_frame, "TaxID")

# %% [markdown]
# ## What strains are most popular each year?

# %%
df.resample('Y').sum().idxmax(axis=1)

# %% [markdown]
# ## What is the distribution of species over time?
#
# The plot is very spiky- some plots have many more deposits than others. I wonder why?

# %%
col_order = df.sum().sort_values(inplace=False).index
df1=np.split(df[col_order], [-20], axis=1)

#Combines these dataframes, summing all small values to combine them
final_df = pandas.concat([df1[1], df1[0].sum(axis=1)], axis=1)

#Make the plot! 
final_df.plot.area()
plt.ylabel("number of bacterial species deposited in NCBI per month")
plt.show()

# %% [markdown]
# This is the same thing, but cumulative distribution.

# %%
final_df.cumsum().plot.area(legend=False)
plt.ylabel("Cumulative number of bacterial species in NCBI")
plt.show()

# %% [markdown]
# ## Why are there big spikes?

# %% [markdown]
# Beth suggested the spikes in the data were caused by large institutes unloading all their data to NCBI at once.
#
# If this is true, we would expect entries in the spikes to be dominated by one Center. Which does appear to be the case (see violin plot below).
#
# This analysis is really crude, though: I just took really big peaks (>6000 entries). This misses some early peaks.

# %%
#get index of spikes. 
#this is very crude: just take all the big ones. 
#How would I get it responsive to actual 
spikes = final_df.sum(axis=1)[final_df.sum(axis=1) > 6000].index
Center_df = group_df_by(data_frame, "Center")

# %%
#new box because group_df_by is so slow 
spike_df = Center_df.loc[spikes]

#remove one-entry months, as they will screw with values. 
Center_df = Center_df[Center_df.sum(axis=1) > 1]

non_spike_df = Center_df.drop(spikes)
spike_proportion = spike_df.max(axis=1)/spike_df.sum(axis=1)
spike_proportion = spike_proportion.tolist()
non_spike_proportion = non_spike_df.max(axis=1)/non_spike_df.sum(axis=1)
non_spike_proportion = non_spike_proportion.tolist()

# %%
non_spike_df.max(axis=1)/non_spike_df.sum(axis=1)

twosample_results = scipy.stats.ttest_ind(spike_proportion, non_spike_proportion)

matrix_twosample = [
    ['', 'Test Statistic', 'p-value'],
    ['Sample Data', twosample_results[0], twosample_results[1]]
]
matrix_twosample

data = [spike_proportion, non_spike_proportion]
pos = [1, 2]

plt.figure()
ax = plt.subplot(111)
plt.violinplot(data)
ax.set_xticks(pos)
ax.set_xticklabels(["spike months", "normal months"]); #semicolon suppresses chatty matplotlib
plt.ylabel("Proportion of entries from largest contributor");

matrix_twosample[1][2]

# %% [markdown]
# We would also expect so see a correlation between number of entries (corrected for time?) and proportion of entries from one Center.
#
# This does seem to be the case, but the really small entries are throwing out the data a bit.
#
# I'm also still not correcting for the increase in deposition over time.

# %%
proportion_of_centers = Center_df.max(axis=1)/Center_df.sum(axis=1)

total_entries = Center_df.sum(axis=1)

plt.scatter(total_entries, proportion_of_centers)
plt.plot(np.unique(total_entries), #https://stackoverflow.com/questions/19068862/how-to-overplot-a-line-on-a-scatter-plot-in-python/19069001#19069001
         np.poly1d(np.polyfit(total_entries, proportion_of_centers, 1))(np.unique(total_entries)))
plt.xlabel("Total number of entries")
plt.ylabel("Proportion of entries from largest contributor");

# %% [markdown]
# ## Correcting for increasing entries with time
#
# If we correct for the total number of entries, by calculating a rolling average, and looking at how the data points compare to that, we get a consistently positive relationship.
#
# I'm not sure how to choose the rolling average index. Three zeems legit? The data looks a little odd in the larger values, so I'm wary.

# %%
for i in range(2, 10): 
    total_entries_rolling = total_entries.rolling(i).mean()
    proportion = total_entries/total_entries_rolling
    df = pandas.concat([proportion, proportion_of_centers], 
                       axis = 1, 
                       keys = ["proportion", "proportion_of_centers"]).dropna()
    plt.scatter(df.proportion, df.proportion_of_centers)
    plt.xlabel("Total entries divided by rolling average")
    plt.ylabel("Proportion of entries from largest contributor")
    plt.plot(np.unique(df.proportion), #https://stackoverflow.com/questions/19068862/how-to-overplot-a-line-on-a-scatter-plot-in-python/19069001#19069001
         np.poly1d(np.polyfit(df.proportion, df.proportion_of_centers, 1))(np.unique(df.proportion)))
    title = "Rolling average of " + str(i) + " values"
    plt.title(title)
    #print (proportion)
    plt.show()

# %% [markdown]
# ## What does this tell us?
#
# 1) In some months, there are a *lot* more bacterial species being deposited into NCBI than others.
# - this appears to be big depositors adding lots of data
#
# 2) Most bacterial species being sequenced are not "the big 20".
# - What is driving the increase in NCBI submissions? Model or non-model species?

# %% [markdown]
# ## To-Do
#
# - make the code nicer- It'd be nice to be able to make different plots of different variables, without having to re-group the data frame each time. This must be possible.
# - axes etc for the plots!
# - stats
# - more sensible analysis of who is depositing

# %%
data_frame
# Out:
#                                                  #Organism/Name    TaxID  \
# Release Date
# 2001-11-07    Salmonella enterica subsp. enterica serovar Ty...   220341
# 2006-02-13        Staphylococcus aureus subsp. aureus NCTC 8325    93061
# 2001-09-27    Campylobacter jejuni subsp. jejuni NCTC 11168 ...   192222
# 2011-12-09                         Pseudomonas fluorescens F113  1114970
# 2001-11-08                         Listeria monocytogenes EGD-e   169963
# 2001-09-07                     Mycobacterium tuberculosis H37Rv    83332
# 2008-12-16                               Escherichia coli IAI39   585057
# 2001-10-03                          Streptococcus pneumoniae R6   171101
# 2002-12-20                Staphylococcus epidermidis ATCC 12228   176280
# 2003-04-16                           Bacillus cereus ATCC 14579   226900
# 2001-10-15                                 Yersinia pestis CO92   214092
# 2001-01-09              Lactococcus lactis subsp. lactis Il1403   272623
# 2001-11-28    Xanthomonas campestris pv. campestris str. ATC...   190485
# 2006-07-25                   Clostridium perfringens ATCC 13124   195103
# 1995-07-25                       Haemophilus influenzae Rd KW20    71421
# 2001-10-03                                Eli Lilly and Company
# 2002-12-20                       Chinese National HGC, Shanghai
# 2003-04-16                                                 INRA
# 2001-10-15                                     Sanger Institute
# 2001-01-09                                                 INRA
# 2001-11-28                  Sao Paulo state (Brazil) Consortium
# 2006-07-25                                                 TIGR
# 1995-07-25                                                 TIGR
# 2000-02-25                                                 TIGR
# 1997-08-06                                                 TIGR
# 2001-12-27                                      Univ. Minnesota
# 2001-01-25                        School of Veterinary Medicine
# 2003-02-24                                            Genoscope
# 2007-02-23                  National Research Council of Canada
# 2003-07-25                                                 CNRS
# 2001-04-10                                       Univ. Oklahoma
# 2002-10-21                       Chinese National HGC, Shanghai
# 2014-12-10                                       CNRS - UPR2355
# 2000-06-02                  Sao Paulo state (Brazil) Consortium
# 2009-01-27                             Agrobacterium consortium
# 2002-05-16                            J. Craig Venter Institute
# 2002-10-16                     Microbial Genome Center of ChMPH
# 2002-02-13                                  Integrated Genomics
# ...                                                         ...
# 2017-10-10                             University of Queensland
# 2018-03-06    National institute for communicable disease co...
# 2018-03-19                         China Aricultural University
# 2018-05-01                    Institute for Infectious Diseases
# 2018-05-01                    Institute for Infectious Diseases
# 2018-05-01                    Institute for Infectious Diseases
# 2018-05-02         National Institute for Communicable Diseases
# 2018-05-23                                          Mayo Clinic
# 2016-12-02                           academisch medisch centrum
# 2016-12-02                           academisch medisch centrum
# 2016-12-08                                                RCPCM
# 2016-12-09                                               Moscow
# 2017-02-17                               Kalmar county hospital
# 2017-02-17                               Kalmar county hospital
# 2017-09-07                                               Ausgem
# 2017-09-06                                               Ausgem
# 2016-10-12                            Christian Medical College
# 2014-11-13                             University of Washington
# 2014-11-13                             University of Washington
# 2014-11-13                             University of Washington
# 2014-11-13                             University of Washington
# 2014-11-13                             University of Washington
# 2014-11-13                             University of Washington
# 2014-11-13                             University of Washington
# 2014-11-13                             University of Washington
# 2014-11-13                             University of Washington
# 2014-11-13                             University of Washington
# 2013-12-16                   University of California, Berkeley
# 2014-11-13                             University of Washington
# 2014-11-13                             University of Washington
#
#              BioSample Accession Assembly Accession Reference  \
# Release Date
# 2001-11-07          SAMEA1705914    GCA_000195995.1      REFR
# 2006-02-13          SAMN02604235    GCA_000013425.1      REFR
# 2001-09-27          SAMEA1705929    GCA_000009085.1      REFR
# 2011-12-09          SAMN02604099    GCA_000237065.1      REFR
# 2001-11-08          SAMEA3138329    GCA_000196035.1      REFR
# 2001-09-07          SAMEA3138326    GCA_000195955.2      REFR
# 2008-12-16          SAMEA3138234    GCA_000026345.1      REFR
# 2001-10-03          SAMN02603218    GCA_000007045.1      REFR
# 2002-12-20          SAMN02603126    GCA_000007645.1      REFR
# 2003-04-16          SAMN02603340    GCA_000007825.1      REFR
# 2001-10-15          SAMEA1705942    GCA_000009065.1      REFR
# 2001-01-09          SAMN02603339    GCA_000006865.1      REFR
# 2001-11-28          SAMN02603845    GCA_000007145.1      REFR
# 2006-07-25          SAMN02604008    GCA_000013285.1      REFR
# 1995-07-25          SAMN02603991    GCA_000027305.1      REFR
# 2000-02-25          SAMN02603997    GCA_000008805.1      REFR
# 1997-08-06          SAMN02603995    GCA_000008525.1      REFR
# 2001-12-27          SAMN02604086    GCA_000007865.1      REFR
# 2001-01-25         SAMEA20450668    GCA_000195835.2      REFR
# 2003-02-24          SAMN02603248    GCA_000007485.1      REFR
# 2007-02-23          SAMN02603665    GCA_000015885.1         -
# 2003-07-25          SAMN02603142    GCA_000007925.1      REFR
# 2001-04-10          SAMN02604089    GCA_000006785.2      REFR
# 2002-10-21          SAMN02603127    GCA_000092565.1      REFR
# 2014-12-10          SAMN03198226    GCA_000800615.1      REFR
# 2000-06-02          SAMN02603773    GCA_000006725.1      REFR
# 2009-01-27          SAMN02602977    GCA_000016265.1         -
# 2002-05-16          SAMN02603432    GCA_000007845.1      REFR
# 2002-10-16          SAMN02603599    GCA_000006925.2      REFR
# 2002-02-13          SAMN02603417    GCA_000007325.1      REFR
# ...                          ...                ...       ...
# 2017-10-10          SAMN06454698    GCA_002492025.1         -
# 2018-03-06          SAMN03384332    GCA_002972555.1         -
# 2018-03-19          SAMN07983284    GCA_003009535.1         -
# 2018-05-01          SAMN08985452    GCA_003076675.1         -
# 2018-05-01          SAMN08985453    GCA_003076715.1         -
# 2018-05-01          SAMN08985455    GCA_003076735.1         -
# 2018-05-02          SAMN07714117    GCA_003086215.1         -
# 2018-05-23          SAMN08295014    GCA_003149995.1         -
# 2016-12-02          SAMEA4350771    GCA_900093935.1         -
# 2016-12-02          SAMEA4350770    GCA_900094035.1         -
# 2016-12-08         SAMEA18415168    GCA_900143315.1         -
# 2016-12-09         SAMEA23867668    GCA_900148645.1         -
# 2017-02-17          SAMEA4483550    GCA_900166725.1         -
# 2017-02-17          SAMEA4483549    GCA_900166775.1         -
# 2017-09-07        SAMEA104140488    GCA_900195315.1         -
# 2017-09-06        SAMEA104140525    GCA_900196155.1         -
# 2016-10-12          SAMN04965949    GCA_001758055.1         -
# 2014-11-13          SAMN02802090    GCA_000777775.1         -
# 2014-11-13          SAMN02802091    GCA_000777875.1         -
# 2014-11-13          SAMN02802075    GCA_000778145.1         -
# 2014-11-13          SAMN02802071    GCA_000778195.1         -
# 2014-11-13          SAMN02802066    GCA_000778255.1         -
# 2014-11-13          SAMN02802025    GCA_000778625.1         -
# 2014-11-13          SAMN02802036    GCA_000778805.1         -
# 2014-11-13          SAMN02802039    GCA_000778875.1         -
# 2014-11-13          SAMN02802055    GCA_000779195.1         -
# 2014-11-13          SAMN02802020    GCA_000779355.1         -
# 2013-12-16          SAMN02316559    GCA_000508485.1         -
# 2014-11-13          SAMN02802141    GCA_000777015.1         -
# 2014-11-13          SAMN02802086    GCA_000777915.1         -
#
#                                                        FTP Path  \
# Release Date
# 2001-11-07    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2006-02-13    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2001-09-27    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2011-12-09    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2001-11-08    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2001-09-07    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2008-12-16    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2001-10-03    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2002-12-20    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2003-04-16    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2001-10-15    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2001-01-09    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2001-11-28    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2006-07-25    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 1995-07-25    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2000-02-25    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 1997-08-06    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2001-12-27    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2001-01-25    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2003-02-24    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2007-02-23    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2003-07-25    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2001-04-10    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2002-10-21    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2014-12-10    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2000-06-02    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2009-01-27    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2002-05-16    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2002-10-16    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2002-02-13    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# ...                                                         ...
# 2017-10-10    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/002...
# 2018-03-06    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/002...
# 2018-03-19    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/003...
# 2018-05-01    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/003...
# 2018-05-01    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/003...
# 2018-05-01    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/003...
# 2018-05-02    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/003...
# 2018-05-23    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/003...
# 2016-12-02    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/900...
# 2016-12-02    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/900...
# 2016-12-08    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/900...
# 2016-12-09    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/900...
# 2017-02-17    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/900...
# 2017-02-17    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/900...
# 2017-09-07    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/900...
# 2017-09-06    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/900...
# 2016-10-12    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/001...
# 2014-11-13    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2014-11-13    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2014-11-13    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2014-11-13    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2014-11-13    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2014-11-13    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2014-11-13    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2014-11-13    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2014-11-13    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2014-11-13    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2013-12-16    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2014-11-13    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
# 2014-11-13    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...
#
#                                Pubmed ID           Strain
# Release Date
# 2001-11-07                      11677608             CT18
# 2006-02-13                             -        NCTC 8325
# 2001-09-27             10688204,17565669       NCTC 11168
# 2011-12-09                      22328765             F113
# 2001-11-08    11679669,16428782,19448609            EGD-e
# 2001-09-07     9634230,12368430,20980199            H37Rv
# 2008-12-16                      19165319            IAI39
# 2001-10-03                      11544234               R6
# 2002-12-20                      12950922       ATCC 12228
# 2003-04-16                      12721630       ATCC 14579
# 2001-10-15    11586360,12834539,19055764             CO92
# 2001-01-09                      11337471           IL1403
# 2001-11-28                      12024217       ATCC 33913
# 2006-07-25                      16825665       ATCC 13124
# 1995-07-25       7542800,7542802,8805245                -
# 2000-02-25                      10710307             MC58
# 1997-08-06     9252185,10477311,14500513            26695
# 2001-12-27                      16116077             K-10
# 2001-01-25                             -        AF2122/97
# 2003-02-24                      12902375            Twist
# 2007-02-23                      18065534              L20
# 2003-07-25                      12917486  CCMP1375; SS120
# 2001-04-10             11296296,24733896            SF370
# 2002-10-21                      12712204            56601
# 2014-12-10                      25635023           PA14H7
# 2000-06-02                      10910347             9a5c
# 2009-01-27                      19251847              K84
# 2002-05-16                      12721629             Ames
# 2002-10-16                      12384590              301
# 2002-02-13                      11889109       ATCC 25586
# ...                                  ...              ...
# 2017-10-10                      28894102          UBA7137
# 2018-03-06                      27924811        HT2012015
# 2018-03-19                      29535301          sc12-92
# 2018-05-01                             -             EC-4
# 2018-05-01                             -            EC-16
# 2018-05-01                             -           CMY-33
# 2018-05-02                             -        HN503E1II
# 2018-05-23                             -      CIM:MAG 560
# 2016-12-02                             -         CG40C.C2
# 2016-12-02                             -         CG05C.C2
# 2016-12-08                             -         Hp_23-13
# 2016-12-09                             -         Hp_23-13
# 2017-02-17                             -               10
# 2017-02-17                             -                9
# 2017-09-07                             -          F1_409D
# 2017-09-06                             -            F2_45
# 2016-10-12                             -            FC673
# 2014-11-13                      25373147         upec-263
# 2014-11-13                      25373147         upec-264
# 2014-11-13                      25373147          upec-25
# 2014-11-13                      25373147         upec-246
# 2014-11-13                      25373147         upec-241
# 2014-11-13                      25373147         upec-204
# 2014-11-13                      25373147         upec-214
# 2014-11-13                      25373147         upec-217
# 2014-11-13                      25373147         upec-231
# 2014-11-13                      25373147          upec-20
# 2013-12-16                             -                -
# 2014-11-13                      25373147           upec-5
# 2014-11-13                      25373147          upec-26
#
# [150766 rows x 23 columns]

# %%
my_file = "prokaryotes.txt" #hardcoded- bad! 
# reading in initial data set:
data_frame = pandas.read_csv(my_file, sep = '\t', header = 'infer', 
                             low_memory = False)

#stolen from Beth. Should make data imports etc into some functions. 
#How would we write tests for that? 
data_frame['Release Date'] = pandas.to_datetime(data_frame['Release Date'])

#set index
data_frame.index = data_frame['Release Date']
