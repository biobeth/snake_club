# %% [markdown]
# # How do bacterial strains deposited in NCBI change over time?

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>
#
# <!--- This produces the "show code" button. From http://chris-said.io/2016/02/13/how-to-make-polished-jupyter-presentations-with-optional-code-visibility/ Note that this will break code when you try to save the notebook as pdf--->

# %%
#imports 
#%reset
import pandas
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
my_file = "prokaryotes.txt" #hardcoded- bad! 
# reading in initial data set:
data_frame = pandas.read_csv(my_file, sep = '\t', header = 'infer', 
                             low_memory = False)

#stolen from Beth. Should make data imports etc into some functions. 
#How would we write tests for that? 
data_frame['Release Date'] = pandas.to_datetime(data_frame['Release Date'])

#set index
data_frame.index = data_frame['Release Date']

def group_df_by(data_frame, grouping, time_interval = "M"): 
    """
    Groups data_frame by the grouping value. 
    grouping must be a column name of data_frame  
    (Look, I used an assert statement!)
    """
    #count number of submissions every month
    assert grouping in data_frame.columns
    #data_frame = data_frame.loc[:, "TaxID"] something like this should speed functuion up 
    data_frame = data_frame.groupby(grouping).resample(time_interval).count()
    data_frame = data_frame[grouping].unstack(grouping)
    return (data_frame)
    
df = group_df_by(data_frame, "TaxID")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-c243cbc87aec> in <module>()
#      24     return (data_frame)
#      25
# ---> 26 df = group_df_by(data_frame, "TaxID")
#
# <ipython-input-77-c243cbc87aec> in group_df_by(data_frame, grouping, time_interval)
#      20     assert grouping in data_frame.columns
#      21     #data_frame = data_frame.loc[:, "TaxID"] something like this should speed functuion up
# ---> 22     data_frame = data_frame.groupby(grouping).resample(time_interval).count()
#      23     data_frame = data_frame[grouping].unstack(grouping)
#      24     return (data_frame)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/resample.py in f(self, _method)
#     774 for method in ['count']:
#     775     def f(self, _method=method):
# --> 776         return self._downsample(_method)
#     777     f.__doc__ = getattr(GroupBy, method).__doc__
#     778     setattr(Resampler, method, f)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/resample.py in _apply(self, f, **kwargs)
#     867             return x.apply(f, **kwargs)
#     868
# --> 869         result = self._groupby.apply(func)
#     870         return self._wrap_result(result)
#     871
#
# ~/.local/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     916         with option_context('mode.chained_assignment', None):
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#     920
#
# ~/.local/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# ~/.local/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2255                 hasattr(splitter, 'fast_apply') and axis == 0):
#    2256             try:
# -> 2257                 values, mutated = splitter.fast_apply(f, group_keys)
#    2258                 return group_keys, values, mutated
#    2259             except reduction.InvalidApply:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in fast_apply(self, f, names)
#    5086         sdata = self._get_sorted_data()
#    5087         results, mutated = reduction.apply_frame_axis0(sdata, f, names,
# -> 5088                                                        starts, ends)
#    5089
#    5090         return results, mutated
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.apply_frame_axis0()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/resample.py in func(x)
#     863
#     864             if isinstance(f, compat.string_types):
# --> 865                 return getattr(x, f)(**kwargs)
#     866
#     867             return x.apply(f, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/resample.py in f(self, _method)
#     774 for method in ['count']:
#     775     def f(self, _method=method):
# --> 776         return self._downsample(_method)
#     777     f.__doc__ = getattr(GroupBy, method).__doc__
#     778     setattr(Resampler, method, f)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/resample.py in _downsample(self, how, **kwargs)
#     897         **kwargs : kw args passed to how function
#     898         """
# --> 899         self._set_binner()
#     900         how = self._is_cython_func(how) or how
#     901         ax = self.ax
#
# ~/.local/lib/python3.6/site-packages/pandas/core/resample.py in _set_binner(self)
#     146
#     147         if self.binner is None:
# --> 148             self.binner, self.grouper = self._get_binner()
#     149
#     150     def _get_binner(self):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/resample.py in _get_binner(self)
#     154         """
#     155
# --> 156         binner, bins, binlabels = self._get_binner_for_time()
#     157         bin_grouper = BinGrouper(bins, binlabels, indexer=self.groupby.indexer)
#     158         return binner, bin_grouper
#
# ~/.local/lib/python3.6/site-packages/pandas/core/resample.py in _get_binner_for_time(self)
#     886         if self.kind == 'period':
#     887             return self.groupby._get_time_period_bins(self.ax)
# --> 888         return self.groupby._get_time_bins(self.ax)
#     889
#     890     def _downsample(self, how, **kwargs):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/resample.py in _get_time_bins(self, ax)
#    1306                                         end=last,
#    1307                                         tz=tz,
# -> 1308                                         name=ax.name)
#    1309
#    1310         # GH 15549
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/datetimes.py in __new__(cls, data, freq, start, end, periods, tz, normalize, closed, ambiguous, dayfirst, yearfirst, dtype, copy, name, verify_integrity)
#     379                 return cls._generate(start, end, periods, name, freq, tz=tz,
#     380                                      normalize=normalize, closed=closed,
# --> 381                                      ambiguous=ambiguous)
#     382
#     383         if not isinstance(data, (np.ndarray, Index, ABCSeries)):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/datetimes.py in _generate(cls, start, end, periods, name, freq, tz, normalize, ambiguous, closed)
#     572                                               freq=freq, name=name)
#     573                 else:
# --> 574                     index = _generate_regular_range(start, end, periods, freq)
#     575
#     576                 if tz is not None and getattr(index, 'tz', None) is None:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/datetimes.py in _generate_regular_range(start, end, periods, freq)
#    2597                              periods=periods, offset=freq)
#    2598
# -> 2599         dates = list(xdr)
#    2600         # utc = len(dates) > 0 and dates[0].tzinfo is not None
#    2601         data = tools.to_datetime(dates)
#
# ~/.local/lib/python3.6/site-packages/pandas/tseries/offsets.py in generate_range(start, end, periods, offset, time_rule)
#    2412
#    2413     start = to_datetime(start)
# -> 2414     end = to_datetime(end)
#    2415
#    2416     if start and not offset.onOffset(start):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     467             result = _convert_listlike(arg, box, format)
#     468     else:
# --> 469         result = _convert_listlike(np.array([arg]), box, format)[0]
#     470
#     471     return result
#
# ~/.local/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     366                     dayfirst=dayfirst,
#     367                     yearfirst=yearfirst,
# --> 368                     require_iso8601=require_iso8601
#     369                 )
#     370
#
# KeyboardInterrupt:

# %% [markdown]
# ## What strains are most popular each year?

# %%
df.resample('Y').sum().idxmax(axis=1)
# Out:
# Release Date
# 1995-12-31      71421
# 1996-12-31     272634
# 1997-12-31      85962
# 1998-12-31     243232
# 1999-12-31      85963
# 2000-12-31      64091
# 2001-12-31        882
# 2002-12-31      36870
# 2003-12-31      59919
# 2004-12-31     279010
# 2005-12-31       1140
# 2006-12-31      56780
# 2007-12-31     419947
# 2008-12-31        340
# 2009-12-31       1405
# 2010-12-31     443255
# 2011-12-31     796937
# 2012-12-31    1074919
# 2013-12-31       1639
# 2014-12-31        562
# 2015-12-31       1313
# 2016-12-31       1313
# 2017-12-31        562
# 2018-12-31        562
# Freq: A-DEC, dtype: int64

# %% [markdown]
# ## What is the distribution of species over time?
#
# The plot is very spiky- some plots have many more deposits than others. I wonder why?

# %%
col_order = df.sum().sort_values(inplace=False).index
df1=np.split(df[col_order], [-20], axis=1)

#Combines these dataframes, summing all small values to combine them
final_df = pandas.concat([df1[1], df1[0].sum(axis=1)], axis=1)

#Make the plot! 
final_df.plot.area()
plt.show()

# %% [markdown]
# This is the same thing, but cumulative distribution.

# %%
final_df.cumsum().plot.area(legend=False)
plt.show()

# %% [markdown]
# ## Why are there big spikes?

# %% [markdown]
# Beth suggested the spikes in the data were caused by large institutes unloading all their data to NCBI at once.
#
# If this is true, we would expect entries in the spikes to be dominated by one Center. Is this true?

# %%
#get index of spikes. 
#this is very crude: just take all the big ones. 
#How would I get it responsive to actual 
spikes = final_df.sum(axis=1)[final_df.sum(axis=1) > 6000].index
Center_df = group_df_by(data_frame, "Center")

# %%
#new box because group_df_by is so slow 
spike_df = Center_df.loc[spikes]
non_spike_df = Center_df.drop(spikes)
# Out:
# Center              Lanzhou Institute of Husbandry and Pharmaceutical Sciences of CAAS   \
# Release Date
# 1995-07-31                                                  NaN
# 1995-08-31                                                  NaN
# 1995-09-30                                                  NaN
# 1995-10-31                                                  NaN
# 1995-11-30                                                  NaN
# 1995-12-31                                                  NaN
# 1996-01-31                                                  NaN
# 1996-02-29                                                  NaN
# 1996-03-31                                                  NaN
# 1996-04-30                                                  NaN
# 1996-05-31                                                  NaN
# 1996-06-30                                                  NaN
# 1996-07-31                                                  NaN
# 1996-08-31                                                  NaN
# 1996-09-30                                                  NaN
# 1996-10-31                                                  NaN
# 1996-11-30                                                  NaN
# 1996-12-31                                                  NaN
# 1997-01-31                                                  NaN
# 1997-02-28                                                  NaN
# 1997-03-31                                                  NaN
# 1997-04-30                                                  NaN
# 1997-05-31                                                  NaN
# 1997-06-30                                                  NaN
# 1997-07-31                                                  NaN
# 1997-08-31                                                  NaN
# 1997-09-30                                                  NaN
# 1997-10-31                                                  NaN
# 1997-11-30                                                  NaN
# 1997-12-31                                                  NaN
# ...                                                         ...
# 2016-02-29                                                  NaN
# 2016-03-31                                                  NaN
# 2016-04-30                                                  NaN
# 2016-05-31                                                  NaN
# 2016-06-30                                                  NaN
# 2016-07-31                                                  NaN
# 2016-08-31                                                  NaN
# 2016-09-30                                                  NaN
# 2016-10-31                                                  1.0
# 2016-11-30                                                  NaN
# 2016-12-31                                                  NaN
# 2017-01-31                                                  NaN
# 2017-02-28                                                  NaN
# 2017-03-31                                                  NaN
# 2017-04-30                                                  NaN
# 2017-05-31                                                  NaN
# 2017-06-30                                                  NaN
# 2017-07-31                                                  NaN
# 2017-08-31                                                  NaN
# 2017-09-30                                                  NaN
# 2017-10-31                                                  NaN
# 2017-11-30                                                  NaN
# 2017-12-31                                                  NaN
# 2018-01-31                                                  NaN
# 2018-02-28                                                  NaN
# 2018-03-31                                                  NaN
# 2018-04-30                                                  NaN
# 2018-05-31                                                  NaN
# 2018-06-30                                                  NaN
# 2018-07-31                                                  NaN
#
# Center          Federal Universityof Minas Gerais  \
# Release Date
# 1995-07-31                                    NaN
# 1995-08-31                                    NaN
# 1995-09-30                                    NaN
# 1995-10-31                                    NaN
# 1995-11-30                                    NaN
# 1995-12-31                                    NaN
# 1996-01-31                                    NaN
# 1996-02-29                                    NaN
# 1996-03-31                                    NaN
# 1996-04-30                                    NaN
# 1996-05-31                                    NaN
# 1996-06-30                                    NaN
# 1996-07-31                                    NaN
# 1996-08-31                                    NaN
# 1996-09-30                                    NaN
# 1996-10-31                                    NaN
# 1996-11-30                                    NaN
# 1996-12-31                                    NaN
# 1997-01-31                                    NaN
# 1997-02-28                                    NaN
# 1997-03-31                                    NaN
# 1997-04-30                                    NaN
# 1997-05-31                                    NaN
# 1997-06-30                                    NaN
# 1997-07-31                                    NaN
# 1997-08-31                                    NaN
# 1997-09-30                                    NaN
# 1997-10-31                                    NaN
# 1997-11-30                                    NaN
# 1997-12-31                                    NaN
# ...                                           ...
# 2016-02-29                                    NaN
# 2016-03-31                                    NaN
# 2016-04-30                                    NaN
# 2016-05-31                                    NaN
# 2016-06-30                                    NaN
# 2016-07-31                                    NaN
# 2016-08-31                                    NaN
# 2016-09-30                                    NaN
# 2016-10-31                                    NaN
# 2016-11-30                                    NaN
# 2016-12-31                                    NaN
# 2017-01-31                                    NaN
# 2017-02-28                                    NaN
# 2017-03-31                                    NaN
# 2017-04-30                                    NaN
# 2017-05-31                                    NaN
# 2017-06-30                                    NaN
# 2017-07-31                                    NaN
# 2017-08-31                                    NaN
# 2017-09-30                                    NaN
# 2017-10-31                                    NaN
# 2017-11-30                                    NaN
# 2017-12-31                                    NaN
# 2018-01-31                                    NaN
# 2018-02-28                                    NaN
# 2018-03-31                                    NaN
# 2018-04-30                                    NaN
# 2018-05-31                                    NaN
# 2018-06-30                                    NaN
# 2018-07-31                                    NaN
#
# Center         Arizona State Public Health Laboratory  \
# Release Date
# 1995-07-31                                        NaN
# 1995-08-31                                        NaN
# 1995-09-30                                        NaN
# 1995-10-31                                        NaN
# 1995-11-30                                        NaN
# 1995-12-31                                        NaN
# 1996-01-31                                        NaN
# 1996-02-29                                        NaN
# 1996-03-31                                        NaN
# 1996-04-30                                        NaN
# 1996-05-31                                        NaN
# 1996-06-30                                        NaN
# 1996-07-31                                        NaN
# 1996-08-31                                        NaN
# 1996-09-30                                        NaN
# 1996-10-31                                        NaN
# 1996-11-30                                        NaN
# 1996-12-31                                        NaN
# 1997-01-31                                        NaN
# 1997-02-28                                        NaN
# 1997-03-31                                        NaN
# 1997-04-30                                        NaN
# 1997-05-31                                        NaN
# 1997-06-30                                        NaN
# 1997-07-31                                        NaN
# 1997-08-31                                        NaN
# 1997-09-30                                        NaN
# 1997-10-31                                        NaN
# 1997-11-30                                        NaN
# 1997-12-31                                        NaN
# ...                                               ...
# 2016-02-29                                        0.0
# 2016-03-31                                        0.0
# 2016-04-30                                        1.0
# 2016-05-31                                        NaN
# 2016-06-30                                        NaN
# 2016-07-31                                        NaN
# 2016-08-31                                        NaN
# 2016-09-30                                        NaN
# 2016-10-31                                        NaN
# 2016-11-30                                        NaN
# 2016-12-31                                        NaN
# 2017-01-31                                        NaN
# 2017-02-28                                        NaN
# 2017-03-31                                        NaN
# 2017-04-30                                        NaN
# 2017-05-31                                        NaN
# 2017-06-30                                        NaN
# 2017-07-31                                        NaN
# 2017-08-31                                        NaN
# 2017-09-30                                        NaN
# 2017-10-31                                        NaN
# 2017-11-30                                        NaN
# 2017-12-31                                        NaN
# 2018-01-31                                        NaN
# 2018-02-28                                        NaN
# 2018-03-31                                        NaN
# 2018-04-30                                        NaN
# 2018-05-31                                        NaN
# 2018-06-30                                        NaN
# 2018-07-31                                        NaN
#
# Center         Beijing Academy of Agriculture and Forestry Science  \
# Release Date
# 1995-07-31                                                  NaN
# 1995-08-31                                                  NaN
# 1995-09-30                                                  NaN
# 1995-10-31                                                  NaN
# 1995-11-30                                                  NaN
# 2016-11-30                                                  NaN
# 2016-12-31                                                  NaN
# 2017-01-31                                                  NaN
# 2017-02-28                                                  NaN
# 2017-03-31                                                  NaN
# 2017-04-30                                                  NaN
# 2017-05-31                                                  NaN
# 2017-06-30                                                  NaN
# 2017-07-31                                                  NaN
# 2017-08-31                                                  NaN
# 2017-09-30                                                  NaN
# 2017-10-31                                                  NaN
# 2017-11-30                                                  NaN
# 2017-12-31                                                  NaN
# 2018-01-31                                                  NaN
# 2018-02-28                                                  NaN
# 2018-03-31                                                  NaN
# 2018-04-30                                                  NaN
# 2018-05-31                                                  NaN
# 2018-06-30                                                  NaN
# 2018-07-31                                                  NaN
#
# Center         College of Medicine/Al-Nahrain University   ...    urniidvii  \
# Release Date                                               ...
# 1995-07-31                                           NaN   ...          NaN
# 1995-08-31                                           NaN   ...          NaN
# 1995-09-30                                           NaN   ...          NaN
# 1995-10-31                                           NaN   ...          NaN
# 1995-11-30                                           NaN   ...          NaN
# 1995-12-31                                           NaN   ...          NaN
# 1996-01-31                                           NaN   ...          NaN
# 1996-02-29                                           NaN   ...          NaN
# 1996-03-31                                           NaN   ...          NaN
# 1996-04-30                                           NaN   ...          NaN
# 1996-05-31                                           NaN   ...          NaN
# 1996-06-30                                           NaN   ...          NaN
# 1996-07-31                                           NaN   ...          NaN
# 1996-08-31                                           NaN   ...          NaN
# 1996-09-30                                           NaN   ...          NaN
# 1996-10-31                                           NaN   ...          NaN
# 1996-11-30                                           NaN   ...          NaN
# 1996-12-31                                           NaN   ...          NaN
# 1997-01-31                                           NaN   ...          NaN
# 1997-02-28                                           NaN   ...          NaN
# 1997-03-31                                           NaN   ...          NaN
# 1997-04-30                                           NaN   ...          NaN
# 1997-05-31                                           NaN   ...          NaN
# 1997-06-30                                           NaN   ...          NaN
# 1997-07-31                                           NaN   ...          NaN
# 1997-08-31                                           NaN   ...          NaN
# 1997-09-30                                           NaN   ...          NaN
# 1997-10-31                                           NaN   ...          NaN
# 1997-11-30                                           NaN   ...          NaN
# 1997-12-31                                           NaN   ...          NaN
# ...                                                  ...   ...          ...
# 2016-02-29                                           NaN   ...          NaN
# 2016-03-31                                           NaN   ...          NaN
# 2016-04-30                                           NaN   ...          NaN
# 2016-05-31                                           NaN   ...          NaN
# 2016-06-30                                           NaN   ...          NaN
# 2016-07-31                                           NaN   ...          NaN
# 2016-08-31                                           NaN   ...          NaN
# 2016-09-30                                           NaN   ...          NaN
# 2016-10-31                                           NaN   ...          NaN
# 2016-11-30                                           NaN   ...          NaN
# 2016-12-31                                           NaN   ...          NaN
# 2017-01-31                                           NaN   ...          NaN
# 2017-02-28                                           NaN   ...          NaN
# 2017-03-31                                           NaN   ...          NaN
# 2017-04-30                                           NaN   ...          NaN
# 2017-05-31                                           NaN   ...          NaN
# 2017-06-30                                           NaN   ...          NaN
# 2017-07-31                                           NaN   ...          NaN
# 2017-08-31                                           NaN   ...          NaN
# 2017-09-30                                           NaN   ...          NaN
# 2017-10-31                                           NaN   ...          NaN
# 2017-11-30                                           NaN   ...          NaN
# 2017-12-31                                          10.0   ...          NaN
# 2018-01-31                                           NaN   ...          1.0
# 2018-02-28                                           NaN   ...          NaN
# 2018-03-31                                           NaN   ...          NaN
# 2018-04-30                                           NaN   ...          NaN
# 2018-05-31                                           NaN   ...          NaN
# 2018-06-30                                           NaN   ...          NaN
# 2018-07-31                                           NaN   ...          NaN
#
# Center        usda, ars, aahru  veterinary institute  \
# Release Date
# 1995-07-31                 NaN                   NaN
# 1995-08-31                 NaN                   NaN
# 1995-09-30                 NaN                   NaN
# 1995-10-31                 NaN                   NaN
# 1995-11-30                 NaN                   NaN
# 1995-12-31                 NaN                   NaN
# 1996-01-31                 NaN                   NaN
# 1996-02-29                 NaN                   NaN
# 1996-03-31                 NaN                   NaN
# 1996-04-30                 NaN                   NaN
# 1996-05-31                 NaN                   NaN
# 1996-06-30                 NaN                   NaN
# 1996-07-31                 NaN                   NaN
# 1996-08-31                 NaN                   NaN
# 1996-09-30                 NaN                   NaN
# 1996-10-31                 NaN                   NaN
# 1996-11-30                 NaN                   NaN
# 1996-12-31                 NaN                   NaN
# 1997-01-31                 NaN                   NaN
# 1997-02-28                 NaN                   NaN
# 1997-03-31                 NaN                   NaN
# 1997-04-30                 NaN                   NaN
# 1997-05-31                 NaN                   NaN
# 1997-06-30                 NaN                   NaN
# 1997-07-31                 NaN                   NaN
# 1997-08-31                 NaN                   NaN
# 1997-09-30                 NaN                   NaN
# 1997-10-31                 NaN                   NaN
# 1997-11-30                 NaN                   NaN
# 1997-12-31                 NaN                   NaN
# ...                        ...                   ...
# 2016-02-29                 NaN                   NaN
# 2016-03-31                 NaN                   NaN
# 2016-04-30                 NaN                   NaN
# 2016-05-31                 NaN                   NaN
# 2016-06-30                 NaN                   NaN
# 2016-07-31                 NaN                   NaN
# 2016-08-31                 NaN                   NaN
# 2016-09-30                 NaN                   NaN
# 2016-10-31                 NaN                   NaN
# 2016-11-30                 NaN                   NaN
# 2016-12-31                 NaN                   NaN
# 2017-01-31                 NaN                   NaN
# 2017-02-28                 NaN                   NaN
# 2017-03-31                 NaN                   NaN
# 2017-04-30                 NaN                   NaN
# 2017-05-31                 NaN                   NaN
# 2017-06-30                 NaN                   NaN
# 2017-07-31                 NaN                   NaN
# 2017-08-31                 NaN                   NaN
# 2017-09-30                 NaN                   NaN
# 2017-10-31                 NaN                   NaN
# 2017-11-30                 NaN                   NaN
# 2017-12-31                 NaN                   NaN
# 2018-01-31                 NaN                   NaN
# 2018-02-28                 NaN                   NaN
# 2018-03-31                 NaN                   NaN
# 2018-04-30                 NaN                   NaN
# 2018-05-31                 NaN                   NaN
# 2018-06-30                 NaN                   NaN
# 2018-07-31                 NaN                   NaN
#
# Center        wageningen university and reasearch  world institute of kimchi  \
# Release Date
# 1995-07-31                                    NaN                        NaN
# 1995-08-31                                    NaN                        NaN
# 1995-09-30                                    NaN                        NaN
# 1995-10-31                                    NaN                        NaN
# 1995-11-30                                    NaN                        NaN
# 1995-12-31                                    NaN                        NaN
# 1996-01-31                                    NaN                        NaN
# 1996-02-29                                    NaN                        NaN
# 1996-03-31                                    NaN                        NaN
# 1996-04-30                                    NaN                        NaN
# 1996-05-31                                    NaN                        NaN
# 2016-08-31                    0.0     8.0
# 2016-09-30                    0.0     NaN
# 2016-10-31                    0.0     NaN
# 2016-11-30                    0.0     NaN
# 2016-12-31                    0.0     NaN
# 2017-01-31                    0.0     NaN
# 2017-02-28                    0.0     NaN
# 2017-03-31                    0.0     NaN
# 2017-04-30                    0.0     NaN
# 2017-05-31                    0.0     NaN
# 2017-06-30                    0.0     NaN
# 2017-07-31                    0.0     NaN
# 2017-08-31                    0.0     NaN
# 2017-09-30                    0.0     NaN
# 2017-10-31                    0.0     NaN
# 2017-11-30                    0.0     NaN
# 2017-12-31                    0.0     NaN
# 2018-01-31                    3.0     NaN
# 2018-02-28                   17.0     NaN
# 2018-03-31                    NaN     NaN
# 2018-04-30                    NaN     NaN
# 2018-05-31                    NaN     NaN
# 2018-06-30                    NaN     NaN
# 2018-07-31                    NaN     NaN
#
# [277 rows x 5392 columns]

# %% [markdown]
# ## What does this tell us?
#
# 1) In some months, there are a *lot* more bacterial species being deposited into NCBI than others.
# - Why? Is it big metagenomes papers? Or some of external deadline on submissions?
# - is it one user/center depositing all of the sequences causing the spikes, or multiple?
#
# 2) Most bacterial species being sequenced are not "the big 20".
# - What is driving the increase in NCBI submissions? Model or non-model species?

# %% [markdown]
# ## To-Do
#
# - make the code nicer- It'd be nice to be able to make different plots of different variables, without having to re-group the data frame each time. This must be possible.
# - axes etc for the plots!

# %%
data_frame.index
data_frame.loc[:, "TaxID"].resample("M").count()
#data_frame.resample("M").count()
#data_frame
# Out:
# Release Date
# 1995-07-31        1
# 1995-08-31        0
# 1995-09-30        0
# 1995-10-31        1
# 1995-11-30        0
# 1995-12-31        0
# 1996-01-31        0
# 1996-02-29        0
# 1996-03-31        0
# 1996-04-30        0
# 1996-05-31        0
# 1996-06-30        0
# 1996-07-31        0
# 1996-08-31        0
# 1996-09-30        0
# 1996-10-31        0
# 1996-11-30        1
# 1996-12-31        0
# 1997-01-31        0
# 1997-02-28        0
# 1997-03-31        0
# 1997-04-30        0
# 1997-05-31        0
# 1997-06-30        0
# 1997-07-31        1
# 1997-08-31        1
# 1997-09-30        0
# 1997-10-31        0
# 1997-11-30        2
# 1997-12-31        2
#               ...
# 2016-02-29     6052
# 2016-03-31     1564
# 2016-04-30     1653
# 2016-05-31     1380
# 2016-06-30     1206
# 2016-07-31     1010
# 2016-08-31     1172
# 2016-09-30     1378
# 2016-10-31     6568
# 2016-11-30     2450
# 2016-12-31     3100
# 2017-01-31     2333
# 2017-02-28     1641
# 2017-03-31     4181
# 2017-04-30     2496
# 2017-05-31     2226
# 2017-06-30     3182
# 2017-07-31     1100
# 2017-08-31     2368
# 2017-09-30     5934
# 2017-10-31    11819
# 2017-11-30     3037
# 2017-12-31     1558
# 2018-01-31     2925
# 2018-02-28     2251
# 2018-03-31     3744
# 2018-04-30     2248
# 2018-05-31     3221
# 2018-06-30     6188
# 2018-07-31      894
# Freq: M, Name: TaxID, Length: 277, dtype: int64

# %%
# Out:
# DatetimeIndex(['2015-03-31', '2016-02-29', '2016-10-31', '2017-10-31',
#                '2018-06-30'],
#               dtype='datetime64[ns]', name='Release Date', freq=None)
